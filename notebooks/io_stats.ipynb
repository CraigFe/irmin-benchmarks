# %%
import pandas as pd
from matplotlib import pyplot
import seaborn as sns
import numpy as np
sns.set(color_codes=True)

df = pd.read_csv('/tmp/stats-io-125', index_col=False)

# %%
f, ax = pyplot.subplots(figsize=(14,8))
sns.barplot(x ="benchmark", y="mean(ns)", hue="implementation", errwidth=2, capsize=0.1, data = df)
